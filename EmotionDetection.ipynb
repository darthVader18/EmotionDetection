# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from keras.layers import Flatten, Dense
from keras.models import Model
from keras.preprocessing.image import ImageDataGenerator , img_to_array, load_img
from keras.applications.mobilenet import MobileNet, preprocess_input 
from keras.losses import categorical_crossentropy

# %% [markdown]
# Building our Model To train the data

# %%
# Working with pre trained model 

base_model = MobileNet( input_shape=(224,224,3), include_top= False )

for layer in base_model.layers:
  layer.trainable = False


x = Flatten()(base_model.output)
x = Dense(units=7 , activation='softmax' )(x)

# creating our model.
model = Model(base_model.input, x)

# %%
model.compile(optimizer='adam', loss= categorical_crossentropy , metrics=['accuracy']  )

# %% [markdown]
# Preparing our data using data generator

# %%
train_datagen = ImageDataGenerator(
     zoom_range = 0.2, 
     shear_range = 0.2, 
     horizontal_flip=True, 
     rescale = 1./255
)

train_data = train_datagen.flow_from_directory(directory= "D:/Code/PythonProjects/EmotionDetection/archive/train", 
                                               target_size=(224,224), 
                                               batch_size=32,
                                  )


train_data.class_indices
# Out:
# Found 28709 images belonging to 7 classes.
# {'angry': 0,
#  'disgusted': 1,
#  'fearful': 2,
#  'happy': 3,
#  'neutral': 4,
#  'sad': 5,
#  'surprised': 6}

# %%
val_datagen = ImageDataGenerator(rescale = 1./255 )

val_data = val_datagen.flow_from_directory(directory= "D:/Code/PythonProjects/EmotionDetection/archive/test", 
                                           target_size=(224,224), 
                                           batch_size=32,
                                  )
# Out:
# Found 7178 images belonging to 7 classes.

# %% [markdown]
# Visualizaing the data that is fed to train data gen

# %%
# to visualize the images in the traing data denerator 

t_img , label = train_data.next()

#-----------------------------------------------------------------------------
# function when called will prot the images 
def plotImages(img_arr, label):
  """
  input  :- images array 
  output :- plots the images 
  """
  count = 0
  for im, l in zip(img_arr,label) :
    plt.imshow(im)
    plt.title(im.shape)
    plt.axis = False
    plt.show()
    
    count += 1
    if count == 10:
      break

#-----------------------------------------------------------------------------
# function call to plot the images 
plotImages(t_img, label)

# %% [markdown]
# Having early stopping and model check point

# %%
## having early stopping and model check point 

from keras.callbacks import ModelCheckpoint, EarlyStopping

# early stopping
es = EarlyStopping(monitor='val_accuracy', min_delta= 0.01 , patience= 5, verbose= 1, mode='auto')

# model check point
mc = ModelCheckpoint(filepath="best_model.h5", monitor= 'val_accuracy', verbose= 1, save_best_only= True, mode = 'auto')

# puting call back in a list 
call_back = [es, mc]

# %%
hist = model.fit_generator(train_data, 
                           steps_per_epoch= 10, 
                           epochs= 30, 
                           validation_data= val_data, 
                           validation_steps= 8, 
                           callbacks=[es,mc])
# Out:
# C:\Users\chait\AppData\Local\Temp/ipykernel_24364/564963302.py:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   hist = model.fit_generator(train_data,
# Epoch 1/30
# 10/10 [==============================] - ETA: 0s - loss: 10.9330 - accuracy: 0.2375
# Epoch 00001: val_accuracy improved from -inf to 0.25000, saving model to best_model.h5
# 10/10 [==============================] - 23s 2s/step - loss: 10.9330 - accuracy: 0.2375 - val_loss: 8.1363 - val_accuracy: 0.2500
# Epoch 2/30
# 10/10 [==============================] - ETA: 0s - loss: 10.1730 - accuracy: 0.3344
# Epoch 00002: val_accuracy did not improve from 0.25000
# 10/10 [==============================] - 20s 2s/step - loss: 10.1730 - accuracy: 0.3344 - val_loss: 10.7700 - val_accuracy: 0.2500
# Epoch 3/30
# 10/10 [==============================] - ETA: 0s - loss: 8.6439 - accuracy: 0.3063
# Epoch 00003: val_accuracy improved from 0.25000 to 0.33203, saving model to best_model.h5
# 10/10 [==============================] - 22s 2s/step - loss: 8.6439 - accuracy: 0.3063 - val_loss: 5.3077 - val_accuracy: 0.3320
# Epoch 4/30
# 10/10 [==============================] - ETA: 0s - loss: 5.8980 - accuracy: 0.3938
# Epoch 00004: val_accuracy improved from 0.33203 to 0.46875, saving model to best_model.h5
# 10/10 [==============================] - 21s 2s/step - loss: 5.8980 - accuracy: 0.3938 - val_loss: 5.6889 - val_accuracy: 0.4688
# Epoch 5/30
# 10/10 [==============================] - ETA: 0s - loss: 6.2862 - accuracy: 0.3875
# Epoch 00005: val_accuracy did not improve from 0.46875
# 10/10 [==============================] - 21s 2s/step - loss: 6.2862 - accuracy: 0.3875 - val_loss: 6.8789 - val_accuracy: 0.4492
# Epoch 6/30
# 10/10 [==============================] - ETA: 0s - loss: 7.4321 - accuracy: 0.3625
# Epoch 00006: val_accuracy did not improve from 0.46875
# 10/10 [==============================] - 22s 2s/step - loss: 7.4321 - accuracy: 0.3625 - val_loss: 6.3854 - val_accuracy: 0.4570
# Epoch 7/30
# 10/10 [==============================] - ETA: 0s - loss: 6.3762 - accuracy: 0.4187
# Epoch 00007: val_accuracy did not improve from 0.46875
# 10/10 [==============================] - 21s 2s/step - loss: 6.3762 - accuracy: 0.4187 - val_loss: 5.8561 - val_accuracy: 0.3828
# Epoch 8/30
# 10/10 [==============================] - ETA: 0s - loss: 5.7217 - accuracy: 0.4094
# Epoch 00008: val_accuracy improved from 0.46875 to 0.53125, saving model to best_model.h5
# 10/10 [==============================] - 23s 2s/step - loss: 5.7217 - accuracy: 0.4094 - val_loss: 4.9241 - val_accuracy: 0.5312
# Epoch 9/30
# 10/10 [==============================] - ETA: 0s - loss: 5.6251 - accuracy: 0.4031
# Epoch 00009: val_accuracy did not improve from 0.53125
# 10/10 [==============================] - 23s 2s/step - loss: 5.6251 - accuracy: 0.4031 - val_loss: 4.9427 - val_accuracy: 0.4375
# Epoch 10/30
# 10/10 [==============================] - ETA: 0s - loss: 5.5900 - accuracy: 0.4344
# Epoch 00010: val_accuracy did not improve from 0.53125
# 10/10 [==============================] - 22s 2s/step - loss: 5.5900 - accuracy: 0.4344 - val_loss: 4.8163 - val_accuracy: 0.5039
# Epoch 11/30
# 10/10 [==============================] - ETA: 0s - loss: 5.8052 - accuracy: 0.4000
# Epoch 00011: val_accuracy did not improve from 0.53125
# 10/10 [==============================] - 21s 2s/step - loss: 5.8052 - accuracy: 0.4000 - val_loss: 5.1610 - val_accuracy: 0.3984
# Epoch 12/30
# 10/10 [==============================] - ETA: 0s - loss: 4.5906 - accuracy: 0.4719
# Epoch 00012: val_accuracy did not improve from 0.53125
# 10/10 [==============================] - 20s 2s/step - loss: 4.5906 - accuracy: 0.4719 - val_loss: 5.0453 - val_accuracy: 0.4805
# Epoch 13/30
# 10/10 [==============================] - ETA: 0s - loss: 5.0630 - accuracy: 0.4594
# Epoch 00013: val_accuracy did not improve from 0.53125
# 10/10 [==============================] - 20s 2s/step - loss: 5.0630 - accuracy: 0.4594 - val_loss: 5.1370 - val_accuracy: 0.4375
# Epoch 00013: early stopping

# %%
# Loading the best fit model 
from keras.models import load_model
model = load_model("D:/Code/PythonProjects/EmotionDetection/best_model.h5")

# %%
h =  hist.history
h.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
plt.plot(h['accuracy'])
plt.plot(h['val_accuracy'] , c = "red")
plt.title("acc vs v-acc")
plt.show()

# %%
plt.plot(h['loss'])
plt.plot(h['val_loss'] , c = "red")
plt.title("loss vs v-loss")
plt.show()

# %%
# just to map o/p values 
op = dict(zip( train_data.class_indices.values(), train_data.class_indices.keys()))

# %%
# path for the image to see if it predics correct class

#path = "D:/Code/PythonProjects/EmotionDetection/archive/test/angry/im51.png"
#path = "D:/Code/PythonProjects/EmotionDetection/archive/test/disgusted/im2.png"
#path = "D:/Code/PythonProjects/EmotionDetection/archive/test/fearful/im52.png"
path = "D:/Code/PythonProjects/EmotionDetection/archive/test/happy/im5.png"
#path = "D:/Code/PythonProjects/EmotionDetection/archive/test/neutral/im52.png"
#path = "D:/Code/PythonProjects/EmotionDetection/archive/test/sad/im52.png"
#path = "D:/Code/PythonProjects/EmotionDetection/archive/test/surprised/im52.png"

img = load_img(path, target_size=(224,224) )

i = img_to_array(img)/255
input_arr = np.array([i])
input_arr.shape

pred = np.argmax(model.predict(input_arr))

print(f" the image is of {op[pred]}")

# to display the image  
plt.imshow(input_arr[0])
plt.title("input image")
plt.show()
# Out:
#  the image is of happy
